# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
import os 
import pandas as pd
import os

OCI_ACCESS_KEY_ID = os.environ['OCI_ACCESS_KEY_ID']
OCI_SECRET_ACCESS_KEY = os.environ['OCI_SECRET_ACCESS_KEY']
OCI_REGION ='uk-london-1'
OCI_NAMESPACE = 'lrqgbz9z6zlj'
BUCKET_NAME = 'london-property-sales-price'
bucket_folder = "ppd-download-chunks/"

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('PySparkOCIConnection') \
    .config('spark.jars.packages', 'org.apache.hadoop:hadoop-aws:3.3.4,com.amazonaws:aws-java-sdk-bundle:1.12.506') \
    .config('spark.hadoop.fs.s3a.endpoint', f'https://{OCI_NAMESPACE}.compat.objectstorage.{OCI_REGION}.oraclecloud.com') \
    .config('spark.hadoop.fs.s3a.access.key', OCI_ACCESS_KEY_ID) \
    .config('spark.hadoop.fs.s3a.secret.key', OCI_SECRET_ACCESS_KEY) \
    .config('spark.hadoop.fs.s3a.impl', 'org.apache.hadoop.fs.s3a.S3AFileSystem') \
    .config('spark.hadoop.fs.s3a.path.style.access', 'true') \
    .config('spark.hadoop.fs.s3a.connection.ssl.enabled', 'true') \
    .getOrCreate()

file_path = f's3a://{BUCKET_NAME}/{bucket_folder}/*.parquet'
ppd = spark.read.parquet(file_path, header=True, inferSchema=True)

# %%
ppd.columns
# Out:
# ['TRANSACTION_UNIQUE_IDENTIFIER',
#  'PRICE',
#  'DATE_OF_TRANSFER',
#  'POSTCODE',
#  'PROPERTY_TYPE',
#  'OLD_NEW',
#  'DURATION',
#  'PAON',
#  'SAON',
#  'STREET',
#  'LOCALITY',
#  'TOWN_CITY',
#  'DISTRICT',
#  'COUNTY',
#  'PPD_CATEGORY_TYPE',
#  'RECORD_STATUS_MONTHLY_FILE_ONLY',
#  '__index_level_0__']

# %%
df1 = ppd.filter(
    (F.col('postcode')=='SE10 8GR')
)

# %%
df_ppc = df1.toPandas()

# %%
df_ppc.columns
# Out:
# Index(['TRANSACTION_UNIQUE_IDENTIFIER', 'PRICE', 'DATE_OF_TRANSFER',
#        'POSTCODE', 'PROPERTY_TYPE', 'OLD_NEW', 'DURATION', 'PAON', 'SAON',
#        'STREET', 'LOCALITY', 'TOWN_CITY', 'DISTRICT', 'COUNTY',
#        'PPD_CATEGORY_TYPE', 'RECORD_STATUS_MONTHLY_FILE_ONLY',
#        '__index_level_0__'],
#       dtype='object')

# %%
epc_folder = "epc_test/"
files = os.listdir(epc_folder)
# files.remove(".ipynb_checkpoints")

dfs = []
for f in files:
    tmp = pd.read_csv(epc_folder+f)
    dfs.append(tmp)

epc = pd.concat(dfs,ignore_index=True)

# %%
epc[epc['postcode'].str.contains("SE10 8G")]
# Out:
#                                                   lmk-key  \
# 698                    1504295499922016121315191628378106
# 699                    1504311549312016121315175099969047
# 700                    1504326199922016121315190418278816
# 702                    1504371389412016121315190599969245
# 704                    1504399899962016121315175238978336
# ...                                                   ...
# 123285  a25b29005fd924a316eabc2390c6459ed08ac8d2aa44f1...
# 123290  c1b3a2f6f2586f6808a0861ab7ff073fd43b679fde65d3...
# 123291  c61d3f97ea6d3ca22b04a2553e8d2680055db5fb16f9ef...
# 123298  e864756c3552dcbb54fb30f0edcd0d5b506076175c92c2...
# 123302  faa704a6ebb8586b07ece391ad8b8b6334cc5dca5673d5...
#
#                      address1                     address2 address3  postcode  \
# 698     Flat 13 Blossom House              Hillside Avenue      NaN  SE10 8GB
# 699      Flat 1 Blossom House              Hillside Avenue      NaN  SE10 8GB
# 700     Flat 16 Blossom House              Hillside Avenue      NaN  SE10 8GB
# 702      Flat 6 Blossom House              Hillside Avenue      NaN  SE10 8GB
# 704      Flat 3 Blossom House              Hillside Avenue      NaN  SE10 8GB
# ...                       ...                          ...      ...       ...
# 123285                 FLAT 4  NOAKES HOUSE, 33 ROYAL HILL      NaN  SE10 8GW
# 123290                 FLAT 5  NOAKES HOUSE, 33 ROYAL HILL      NaN  SE10 8GW
# 123291                 FLAT 1  NOAKES HOUSE, 33 ROYAL HILL      NaN  SE10 8GW
# 123298                 FLAT 6  NOAKES HOUSE, 33 ROYAL HILL      NaN  SE10 8GW
# 123302                 FLAT 7  NOAKES HOUSE, 33 ROYAL HILL      NaN  SE10 8GW
#
#        building-reference-number current-energy-rating  \
# 698                    213998478                     B
# 699                    772998478                     B
# 700                   1123998478                     B
# 702                   2592998478                     B
# 704                   3382998478                     B
# ...                          ...                   ...
# 123285               10003342738                     B
# 123290               10003312239                     B
# 123291               10003299793                     B
# 123298               10003314955                     B
# 123302               10003316550                     B
#
#        potential-energy-rating current-energy-efficiency  \
# 698                          B                        86
# 699                          B                        86
# 700                          B                        83
# 702                          B                        85
# 704                          B                        83
# ...                        ...                       ...
# 123285                       B                        89
# 123290                       B                        88
# 123291                       B                        87
# 123298                       B                        89
# 123302                       B                        88
#
#        potential-energy-efficiency  ... local-authority-label  \
# 698                             86  ...             Greenwich
# 699                             86  ...             Greenwich
# 700                             83  ...             Greenwich
# 702                             85  ...             Greenwich
# 704                             83  ...             Greenwich
# ...                            ...  ...                   ...
# 123285                          89  ...             Greenwich
# 123290                          88  ...             Greenwich
# 123291                          87  ...             Greenwich
# 123298                          89  ...             Greenwich
# 123302                          88  ...             Greenwich
#
#             constituency-label posttown construction-age-band  \
# 698     Greenwich and Woolwich   LONDON              NO DATA!
# 699     Greenwich and Woolwich   LONDON              NO DATA!
# 700     Greenwich and Woolwich   LONDON              NO DATA!
# 702     Greenwich and Woolwich   LONDON              NO DATA!
# 704     Greenwich and Woolwich   LONDON              NO DATA!
# ...                        ...      ...                   ...
# 123285  Greenwich and Woolwich   London                  2022
# 123290  Greenwich and Woolwich   London                  2022
# 123291  Greenwich and Woolwich   London                  2022
# 123298  Greenwich and Woolwich   London                  2022
# 123302  Greenwich and Woolwich   London                  2022
#
#          lodgement-datetime            tenure fixed-lighting-outlets-count  \
# 698     2016-12-13 15:19:16           unknown                          5.0
# 699     2016-12-13 15:17:50           unknown                          5.0
# 700     2016-12-13 15:19:04           unknown                          5.0
# 702     2016-12-13 15:19:05           unknown                          5.0
# 704     2016-12-13 15:17:52           unknown                          5.0
# ...                     ...               ...                          ...
# 123285  2022-07-20 13:10:59  Rented (private)                         24.0
# 123290  2022-07-20 13:19:21  Rented (private)                         23.0
# 123291  2022-07-20 13:01:49  Rented (private)                         24.0
# 123298  2022-07-20 13:20:17  Rented (private)                         32.0
# 123302  2022-07-20 13:21:24  Rented (private)                         24.0
#
#        low-energy-fixed-light-count          uprn      uprn-source
# 698                             5.0  1.009163e+10  Address Matched
# 699                             5.0  1.009163e+10  Address Matched
# 700                             5.0  1.009163e+10  Address Matched
# 702                             5.0  1.009163e+10  Address Matched
# 704                             5.0  1.009163e+10  Address Matched
# ...                             ...           ...              ...
# 123285                          NaN  1.001027e+10  Address Matched
# 123290                          NaN  1.001027e+10  Address Matched
# 123291                          NaN  1.001027e+10  Address Matched
# 123298                          NaN  1.001027e+10  Address Matched
# 123302                          NaN  1.001027e+10  Address Matched
#
# [672 rows x 92 columns]

# %%
len(epc)
# Out:
# 157041
